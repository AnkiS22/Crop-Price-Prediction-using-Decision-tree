# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## importing dataset

# %%
df = pd.read_excel('agrilinks dataset.xlsx')

# %%
df
# Out:
#       Sl no. District Name Market Name Commodity Variety Grade  \
# 0          1          Agra     Achnera    Potato    Desi   FAQ
# 1          2          Agra     Achnera    Potato    Desi   FAQ
# 2          3          Agra     Achnera    Potato    Desi   FAQ
# 3          4          Agra     Achnera    Potato    Desi   FAQ
# 4          5          Agra     Achnera    Potato    Desi   FAQ
# ...      ...           ...         ...       ...     ...   ...
# 1822    1823          Agra    Samsabad    Potato   Local   FAQ
# 1823    1824          Agra    Samsabad    Potato   Local   FAQ
# 1824    1825          Agra    Samsabad    Potato   Local   FAQ
# 1825    1826          Agra    Samsabad    Potato   Local   FAQ
# 1826    1827          Agra    Samsabad    Potato   Local   FAQ
#
#       Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0                         900                     1000
# 1                         800                      900
# ...

# %% [markdown]
# ## Data preprocessing

# %%
df.head()
# Out:
#    Sl no. District Name Market Name Commodity Variety Grade  \
# 0       1          Agra     Achnera    Potato    Desi   FAQ
# 1       2          Agra     Achnera    Potato    Desi   FAQ
# 2       3          Agra     Achnera    Potato    Desi   FAQ
# 3       4          Agra     Achnera    Potato    Desi   FAQ
# 4       5          Agra     Achnera    Potato    Desi   FAQ
#
#    Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0                      900                     1000
# 1                      800                      900
# 2                      850                      950
# 3                      800                      900
# 4                      800                      900
#
#    Modal Price (Rs./Quintal) Price Date
# 0                        950 2020-12-30
# 1                        850 2020-12-29
# 2                        900 2020-12-28
# 3                        850 2020-12-27
# 4                        850 2020-12-26

# %%
df.shape
# Out:
# (1827, 10)

# %%
df.size
# Out:
# 18270

# %% [markdown]
# ## Exploratory Data Analysis
# ## To Find Data type and missing values in data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1827 entries, 0 to 1826
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Sl no.                     1827 non-null   int64
#  1   District Name              1827 non-null   object
#  2   Market Name                1827 non-null   object
#  3   Commodity                  1827 non-null   object
#  4   Variety                    1827 non-null   object
#  5   Grade                      1827 non-null   object
#  6   Min Price (Rs./Quintal)    1827 non-null   int64
#  7   Max Price (Rs./Quintal)    1827 non-null   int64
#  8   Modal Price (Rs./Quintal)  1827 non-null   int64
#  9   Price Date                 1827 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(5)
# memory usage: 142.9+ KB

# %% [markdown]
# ## Getting all the unique values in each Column of Data Frame

# %%
df1 = df.copy()

# %%
df1
# Out:
#       Sl no. District Name Market Name Commodity Variety Grade  \
# 0          1          Agra     Achnera    Potato    Desi   FAQ
# 1          2          Agra     Achnera    Potato    Desi   FAQ
# 2          3          Agra     Achnera    Potato    Desi   FAQ
# 3          4          Agra     Achnera    Potato    Desi   FAQ
# 4          5          Agra     Achnera    Potato    Desi   FAQ
# ...      ...           ...         ...       ...     ...   ...
# 1822    1823          Agra    Samsabad    Potato   Local   FAQ
# 1823    1824          Agra    Samsabad    Potato   Local   FAQ
# 1824    1825          Agra    Samsabad    Potato   Local   FAQ
# 1825    1826          Agra    Samsabad    Potato   Local   FAQ
# 1826    1827          Agra    Samsabad    Potato   Local   FAQ
#
#       Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0                         900                     1000
# 1                         800                      900
# ...

# %%
pd.unique(df1['Min Price (Rs./Quintal)'])
# Out:
# array([ 900,  800,  850,  950,  820, 1000, 1350, 1400, 1700, 1650, 2000,
#        2300, 2350, 2550, 2650, 2750, 2800, 2840, 2830, 3750, 2820, 2850,
#        2780, 2640, 2740, 2600, 2700, 2500, 2450, 2400, 2470, 2480, 2460,
#        2420, 2380, 2270, 2280, 2250, 2200, 2240, 2150, 2100, 2050, 2060,
#        2030, 2020, 1970, 2010, 1950, 2040, 1930, 1940, 1920, 1900, 1870,
#        1880, 1800, 1840, 1860, 1850, 1830, 1820, 1750, 1760, 1720, 1730,
#        1580, 1550, 1520, 1500, 1470, 1440, 1430, 1410, 1480, 1450, 1420,
#        1380, 1370, 1360, 1340, 1320, 1330, 1300, 1240, 1200, 1280, 1270,
#        1260, 1250, 1220, 1150, 1230, 1100, 1140, 1180, 1050,  860,  840,
#         870,  880,  920,  940, 2900, 2120, 1925, 1910, 1780, 1600, 1120,
#        1080,  980,  750,  780,  810,  700,  500, 1170,    0, 2680, 2620,
#        2570, 2520, 2445, 2365, 2325, 2320, 2340, 2260, 2220, 2070, 1810,
#        1680, 1660, 1560, 1460, 1160, 1060, 1020, 1040,  830,  930,  650,
# ...

# %%
pd.unique(df1['Max Price (Rs./Quintal)'])
# Out:
# array([1000,  900,  950, 1050,  920, 1100, 1450, 1500, 1800, 1750, 2100,
#        2400, 2450, 2650, 2750, 2850, 2880, 2940, 2930, 3850, 2900, 2910,
#        2950, 2920, 2860, 2720, 2820, 2700, 2680, 2780, 2580, 2600, 2550,
#        2500, 2560, 2530, 2540, 2480, 2460, 2350, 2360, 2300, 2340, 2250,
#        2200, 2150, 2140, 2130, 2120, 2060, 2030, 2090, 2080, 2050, 2020,
#        2010, 2000, 1960, 1980, 1930, 1940, 1880, 1920, 1900, 1840, 1850,
#        1820, 1830, 1710, 1650, 1600, 1580, 1530, 1490, 1480, 1510, 1560,
#        1550, 1460, 1430, 1440, 1400, 1380, 1370, 1360, 1390, 1340, 1260,
#        1280, 1350, 1320, 1300, 1250, 1200, 1220, 1240, 1150,  880,  940,
#         910,  960,  980, 1010, 1020, 1080, 1180, 3100, 3150, 3000, 2800,
#        1950, 1700, 1420, 1410, 1060,  800, 2730, 1870,  850, 1330,  600,
#         750, 1120, 2980,    0, 3050, 2770, 2645, 2565, 2525, 2520, 2420,
#        2380, 2320, 2290, 2220, 2240, 2180, 1990, 1780, 1720, 1670, 1620,
# ...

# %%
pd.unique(df1['Modal Price (Rs./Quintal)'])
# Out:
# array([ 950,  850,  900, 1000,  870, 1050, 1400, 1450, 1750, 1700, 2050,
#        2350, 2400, 2600, 2700, 2800, 2840, 2890, 2880, 3800, 2860, 2870,
#        2900, 2830, 2820, 2680, 2780, 2650, 2640, 2740, 2540, 2550, 2500,
#        2450, 2530, 2520, 2460, 2440, 2420, 2310, 2320, 2300, 2250, 2290,
#        2200, 2150, 2100, 2080, 2060, 2030, 2000, 2040, 1980, 1970, 1960,
#        1930, 1940, 1900, 1920, 1840, 1880, 1890, 1860, 1820, 1800, 1790,
#        1725, 1770, 1780, 1680, 1620, 1600, 1560, 1540, 1550, 1500, 1490,
#        1460, 1470, 1440, 1480, 1520, 1430, 1420, 1370, 1360, 1350, 1340,
#        1335, 1330, 1345, 1290, 1230, 1240, 1320, 1310, 1300, 1270, 1260,
#        1250, 1200, 1150, 1180, 1220, 1210, 1100,  840,  860,  880,  930,
#         910,  920,  940,  960,  970,  980, 1040, 1140,  990,  975, 1110,
#        1950, 2720, 2950, 3000, 3050, 2850, 2810, 2790, 2770, 2750, 2480,
#        2490, 2510, 2470, 2515, 2525, 2380, 2280, 2210, 2240, 2170, 2120,
# ...

# %% [markdown]
# ## Finding Missing values in data set if any

# %%
df.isnull().sum()
# Out:
# Sl no.                       0
# District Name                0
# Market Name                  0
# Commodity                    0
# Variety                      0
# Grade                        0
# Min Price (Rs./Quintal)      0
# Max Price (Rs./Quintal)      0
# Modal Price (Rs./Quintal)    0
# Price Date                   0
# dtype: int64

# %% [markdown]
# ## Descriptive statistics of the Data

# %%
df.describe()
# Out:
#             Sl no.  Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# count  1827.000000              1827.000000              1827.000000
# mean    914.000000              1392.799672              1521.559934
# std     527.553789               562.382569               577.775389
# min       1.000000                 0.000000                 0.000000
# 25%     457.500000              1000.000000              1200.000000
# 50%     914.000000              1250.000000              1370.000000
# 75%    1370.500000              1690.000000              1810.000000
# max    1827.000000              3750.000000              3850.000000
#
#        Modal Price (Rs./Quintal)
# count                1827.000000
# mean                 1474.332239
# std                   555.645961
# min                   550.000000
# 25%                  1115.000000
# 50%                  1310.000000
# 75%                  1780.000000
# max                  3800.000000

# %% [markdown]
# ## Visualising Data
# ## Correlation.

# %%
df1 = df1.drop(['Sl no.'], axis = 1)

# %%
df1
# Out:
#      District Name Market Name Commodity Variety Grade  \
# 0             Agra     Achnera    Potato    Desi   FAQ
# 1             Agra     Achnera    Potato    Desi   FAQ
# 2             Agra     Achnera    Potato    Desi   FAQ
# 3             Agra     Achnera    Potato    Desi   FAQ
# 4             Agra     Achnera    Potato    Desi   FAQ
# ...            ...         ...       ...     ...   ...
# 1822          Agra    Samsabad    Potato   Local   FAQ
# 1823          Agra    Samsabad    Potato   Local   FAQ
# 1824          Agra    Samsabad    Potato   Local   FAQ
# 1825          Agra    Samsabad    Potato   Local   FAQ
# 1826          Agra    Samsabad    Potato   Local   FAQ
#
#       Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0                         900                     1000
# 1                         800                      900
# 2                         850                      950
# 3                         800                      900
# ...

# %%
df1.corr()
# Out:
#                            Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# Min Price (Rs./Quintal)                   1.000000                 0.994270
# Max Price (Rs./Quintal)                   0.994270                 1.000000
# Modal Price (Rs./Quintal)                 0.949157                 0.945178
#
#                            Modal Price (Rs./Quintal)
# Min Price (Rs./Quintal)                     0.949157
# Max Price (Rs./Quintal)                     0.945178
# Modal Price (Rs./Quintal)                   1.000000

# %%
sns.heatmap(df1.corr(), 
            cmap="Paired", 
            linecolor = "Blue" ,
            linewidth= 5 ,  
            cbar= "cividis" ,
            annot=True)
plt.show()

# %% [markdown]
# ## Graphs

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler

# %%
sns.scatterplot(x = df1["Min Price (Rs./Quintal)"], 
                y = df1["Market Name"])
plt.grid()
plt.show()

# %%
sns.scatterplot(x = df1["Max Price (Rs./Quintal)"], 
                y = df1["Market Name"])
plt.grid()
plt.show()

# %%
sns.scatterplot(x = df1["Modal Price (Rs./Quintal)"], 
                y = df1["Market Name"])
plt.grid()
plt.show()

# %%
x = sns.pairplot(df1, hue='Market Name')
plt.show()

# %%
df1
# Out:
#       Sl no. District Name MarketName Commodity Variety Grade  MinPrice  \
# 0          1          Agra    Achnera    Potato    Desi   FAQ       900
# 1          2          Agra    Achnera    Potato    Desi   FAQ       800
# 2          3          Agra    Achnera    Potato    Desi   FAQ       850
# 3          4          Agra    Achnera    Potato    Desi   FAQ       800
# 4          5          Agra    Achnera    Potato    Desi   FAQ       800
# ...      ...           ...        ...       ...     ...   ...       ...
# 1822    1823          Agra   Samsabad    Potato   Local   FAQ      1000
# 1823    1824          Agra   Samsabad    Potato   Local   FAQ      1000
# 1824    1825          Agra   Samsabad    Potato   Local   FAQ      1100
# 1825    1826          Agra   Samsabad    Potato   Local   FAQ      1100
# 1826    1827          Agra   Samsabad    Potato   Local   FAQ      1100
#
#       MaxPrice  ModalPrice
# 0         1000         950
# 1          900         850
# ...

# %%
df1 = df1.drop(['Sl no.'], axis = 1)

# %%
df1
# Out:
#      District Name MarketName Commodity Variety Grade  MinPrice  MaxPrice  \
# 0             Agra    Achnera    Potato    Desi   FAQ       900      1000
# 1             Agra    Achnera    Potato    Desi   FAQ       800       900
# 2             Agra    Achnera    Potato    Desi   FAQ       850       950
# 3             Agra    Achnera    Potato    Desi   FAQ       800       900
# 4             Agra    Achnera    Potato    Desi   FAQ       800       900
# ...            ...        ...       ...     ...   ...       ...       ...
# 1822          Agra   Samsabad    Potato   Local   FAQ      1000      1200
# 1823          Agra   Samsabad    Potato   Local   FAQ      1000      1200
# 1824          Agra   Samsabad    Potato   Local   FAQ      1100      1300
# 1825          Agra   Samsabad    Potato   Local   FAQ      1100      1300
# 1826          Agra   Samsabad    Potato   Local   FAQ      1100      1300
#
#       ModalPrice
# 0            950
# 1            850
# 2            900
# ...

# %%
# %matplotlib inline
plt.rcParams["figure.figsize"]=[16,9]

df1.hist()
plt.show()

# %%
plt.scatter(df1.MarketName, df1.MinPrice,  color='blue')
plt.xlabel("Market Name")
plt.ylabel("Price")
plt.show()

# %%
plt.scatter(df1.MarketName, df1.MaxPrice,  color='blue')
plt.xlabel("Market Name")
plt.ylabel("Price")
plt.show()

# %%
plt.scatter(df1.MarketName, df1.ModalPrice,  color='blue')
plt.xlabel("Market Name")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# ## model building

# %%
df_=df1.drop(['MarketName'],axis=1)
y = df1['MinPrice']

df_=df1.drop(['MinPrice'],axis=1)
df_.describe(include='all')
# Out:
#        District Name MarketName Commodity Variety Grade     MaxPrice  \
# count           1827       1827      1827    1827  1827  1827.000000
# unique             1          8         1       4     1          NaN
# top             Agra    Achnera    Potato    Desi   FAQ          NaN
# freq            1827        306      1827    1367  1827          NaN
# mean             NaN        NaN       NaN     NaN   NaN  1521.559934
# std              NaN        NaN       NaN     NaN   NaN   577.775389
# min              NaN        NaN       NaN     NaN   NaN     0.000000
# 25%              NaN        NaN       NaN     NaN   NaN  1200.000000
# 50%              NaN        NaN       NaN     NaN   NaN  1370.000000
# 75%              NaN        NaN       NaN     NaN   NaN  1810.000000
# max              NaN        NaN       NaN     NaN   NaN  3850.000000
#
#          ModalPrice
# count   1827.000000
# unique          NaN
# top             NaN
# freq            NaN
# mean    1474.332239
# ...

# %%
df_ = df1.drop(['District Name','MarketName','Commodity','Variety','Grade'],axis = 1)

# %%
df_
# Out:
#       MinPrice  MaxPrice  ModalPrice
# 0          900      1000         950
# 1          800       900         850
# 2          850       950         900
# 3          800       900         850
# 4          800       900         850
# ...        ...       ...         ...
# 1822      1000      1200        1100
# 1823      1000      1200        1100
# 1824      1100      1300        1200
# 1825      1100      1300        1200
# 1826      1100      1300        1200
#
# [1827 rows x 3 columns]

# %% [markdown]
# ## these are the features we will be using in model building

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_, y, test_size=0.25)

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor(max_depth = 3)

# %%
model.fit(df_,y)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
ypredict = model.predict(X_train)

# %%
ypredict
# Out:
# array([1396.23978202, 1396.23978202, 2062.72727273, ...,  886.02794411,
#         886.02794411, 1179.27536232])

# %%
from sklearn.tree import export_graphviz

# %%
export_graphviz(model, 'tree.dot')

# %%
import pydotplus
graph = pydotplus.graph_from_dot_data('tree.dot')
# Out:
# tree.dot
# ^
# Expected {'graph' | 'digraph'}, found 't'  (at char 0), (line:1, col:1)

# %%
! dot -Tpng tree.dot -o tree.png
